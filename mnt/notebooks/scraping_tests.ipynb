# %%
# !pip install s3fs boto3
# Out:
# ...
#      |████████████████████████████████| 139 kB 7.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 168 kB 20.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 84 kB 293 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 13.5 MB 9.3 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 144 kB 31.8 MB/s eta 0:00:01
# ...
# ERROR: aiobotocore 2.22.0 has requirement botocore<1.37.4,>=1.37.2, but you'll have botocore 1.37.38 which is incompatible.
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.37.3
#     Uninstalling botocore-1.37.3:
#       Successfully uninstalled botocore-1.37.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
# ...

# %%
# !pip install beautifulsoup4 requests pandas lxml
# Out:
# ...
#      |████████████████████████████████| 12.4 MB 42 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 5.1 MB 12.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 23.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.3 MB 13 kB/s  eta 0:00:01
# ...

# %%
# %cd ..
# Out:
# /app

# %%
# %ls
# Out:
# scraping.ipynb  src/  Untitled.ipynb*

# %%
from src.landing.landing_app import extract_vocation

# %%
extract_vocation("knight")
# Out:
# [2025-12-25 23:53:17] [INFO] - Coletando dados: Open PvP | Vocação 2
# [2025-12-25 23:53:17] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&worldtypes[]=0&category=6&profession=2&currentpage=1
# [2025-12-25 23:53:19] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-25 23:53:22] [INFO] - Total de linhas processadas: 50
# [2025-12-25 23:53:22] [INFO] - Coletando dados: Optional PvP | Vocação 2
# [2025-12-25 23:53:22] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&worldtypes[]=1&category=6&profession=2&currentpage=1
# [2025-12-25 23:53:23] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-25 23:53:25] [INFO] - Total de linhas processadas: 50
# [2025-12-25 23:53:25] [INFO] - Coletando dados: Hardcore PvP | Vocação 2
# ...

# %%
from src.landing.landing_app import extract_category

# %%
extract_category("distance")
# Out:
# [2025-12-27 12:37:30] [INFO] - Extraindo categoria 'distance' (skills)...
# [2025-12-27 12:37:30] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=5&profession=3&currentpage=1
# [2025-12-27 12:37:31] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 12:37:33] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=5&profession=3&currentpage=2
# [2025-12-27 12:37:34] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 12:37:35] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=5&profession=3&currentpage=3
# [2025-12-27 12:37:35] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 12:37:38] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=5&profession=3&currentpage=4
# [2025-12-27 12:37:39] [INFO] - Extraídas 50 linhas da tabela.
# ...

# %%
extract_category("magic_level")
# Out:
# [2025-12-27 12:47:55] [INFO] - Extraindo categoria 'magic_level' (skills)...
# [2025-12-27 12:47:55] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=11&profession=4&currentpage=1
# [2025-12-27 12:47:55] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 12:47:58] [INFO] - Total de linhas processadas: 50
# [2025-12-27 12:47:58] [INFO] - DataFrame validado com sucesso (50 linhas).
# [2025-12-27 12:47:58] [INFO] - Arquivo salvo na Landing: s3a://lakehouse/landing/year=2025/month=12/day=27/skills/magic_level.csv
# {'bucket': 'lakehouse',
#  'key': 'landing/year=2025/month=12/day=27/skills/magic_level.csv',
#  'rows': 50,
#  'columns': ['Rank',
#   'Name',
#   'Vocation',
#   'World',
#   'Level',
#   'Skill Level',
#   'Category'],
#  'timestamp': '2025-12-27T12:47:58.703340'}

# %%
from src.landing.landing_app import extract_category

# %%
extract_category("boss")
# Out:
# [2025-12-27 13:20:17] [INFO] - Extraindo categoria 'boss' (extra)...
# [2025-12-27 13:20:17] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=15&profession=0&currentpage=1
# [2025-12-27 13:20:18] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 13:20:20] [INFO] - Total de linhas processadas: 50
# [2025-12-27 13:20:20] [INFO] - DataFrame validado com sucesso (50 linhas).
# [2025-12-27 13:20:20] [INFO] - Arquivo salvo na Landing: s3a://lakehouse/landing/year=2025/month=12/day=27/extra/boss.csv
# {'bucket': 'lakehouse',
#  'key': 'landing/year=2025/month=12/day=27/extra/boss.csv',
#  'rows': 50,
#  'columns': ['Rank',
#   'Name',
#   'Vocation',
#   'World',
#   'Level',
#   'Points',
#   'Category'],
#  'timestamp': '2025-12-27T13:20:20.564792'}

# %%
extract_category("drome")
# Out:
# [2025-12-27 13:20:30] [INFO] - Extraindo categoria 'drome' (extra)...
# [2025-12-27 13:20:30] [INFO] - Acessando URL: https://www.tibia.com/community/?subtopic=highscores&world=&beprotection=-1&category=14&profession=0&currentpage=1
# [2025-12-27 13:20:30] [INFO] - Extraídas 50 linhas da tabela.
# [2025-12-27 13:20:33] [INFO] - Total de linhas processadas: 50
# [2025-12-27 13:20:33] [INFO] - DataFrame validado com sucesso (50 linhas).
# [2025-12-27 13:20:33] [INFO] - Arquivo salvo na Landing: s3a://lakehouse/landing/year=2025/month=12/day=27/extra/drome.csv
# {'bucket': 'lakehouse',
#  'key': 'landing/year=2025/month=12/day=27/extra/drome.csv',
#  'rows': 50,
#  'columns': ['Rank',
#   'Name',
#   'Vocation',
#   'World',
#   'Level',
#   'Score',
#   'Category'],
#  'timestamp': '2025-12-27T13:20:33.631354'}
